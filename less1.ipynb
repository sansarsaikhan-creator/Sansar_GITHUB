# %% [markdown]
# <a href="https://colab.research.google.com/github/sansarsaikhan-creator/Sansar_GITHUB/blob/main/less1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Эхний кодын хичээл

# %% [markdown]
# ## Colab дээр ажиллах

# %% [markdown]
# ### Жишээ код

# %%
10*52
# Out:
# 520

# %%
 356/7
# Out:
# 50.857142857142854

# %%
print('Сайн уу эх дэлхий минь')
# Out:
# Сайн уу эх дэлхий минь

# %%
import pandas

# %%
import pandas as pd

# %% [markdown]
# Утга оноох үед шууд үүснэ
# Хувьсагчийг тодорхойлох шаардлагагүй

# %% [markdown]
# Хувьсагчийн нэр

# %% [markdown]
# * Заавал үсгээр эхлэх эсвэл (_)
# * Тоогоор эхэлж болохгүй
# * Зөвхөн үсэг тоо болон (_)
# * Том жижиг үсэгнүүд ялгаатай

# %%
a = 'Энд утга заана'
print(a)
# Out:
# Энд утга заана

# %%
_abc = 'end utga baina'
print(_abc)
# Out:
# end utga baina

# %%
Name = 'Sansarsaikhan'
Name = 'Bataa'
print(Name)
# Out:
# Bataa

# %% [markdown]
# # Өгөгдлийн төрлүүд

# %% [markdown]
# ## Numeric төрөл

# %% [markdown]
# integer төрөл

# %%
a = 100
b = 25
c = 2122112213243241324254315
a
b
c
print(a,b,c*2)
# Out:
# 100 25 4244224426486482648508630

# %%
# өгөгдлийн төрөл харах
type(a)
# Out:
# int

# %%
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'int'> <class 'int'>

# %% [markdown]
# # Өгөгдлийн float төрөл

# %%
a = 33.35
a
b = 33,34
b
# Out:
# (33, 34)

# %%
a = 1e9
a
# Out:
# 1000000000.0

# %%
b = 10e6
b
# Out:
# 10000000.0

# %%
c = 10e2
c
# Out:
# 1000.0

# %%
a = 1e-4
a
# Out:
# 0.0001

# %%
b = 1e-2
b
# Out:
# 0.01

# %%
c = -3.14
c
# Out:
# -3.14

# %%
print(type(a),type(b))
# Out:
# <class 'float'> <class 'float'>

# %%
print(type(a),type(b),sep='\n')
# Out:
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ##Complex number

# %%
# j нь язгуур дор -1
a = 5+2j
print(a,type(a))
# Out:
# (5+2j) <class 'complex'>

# %%
# нэмэх үйлдэл
b = a+5+9j
print(b)
# Out:
# (10+11j)

# %%
abs(-1000)
print(-1000)
# Out:
# -1000

# %%
# Модуль авах
abs(-1000)
print(-1000)
# Out:
# -1000

# %%
int (3.14)
# Out:
# 3

# %%
int (3.89)
# Out:
# 3

# %%
float(56)
# Out:
# 56.0

# %%
complex(67)
# Out:
# (67+0j)

# %%
hex(1100876)
# Out:
# '0x10cc4c'

# %% [markdown]
# # Logic төрөл

# %%
o = True
p = False
print(o,p)
# Out:
# True False

# %%
o = True
p = False
type(o)
# Out:
# bool

# %%
(o and p)
# Out:
# False

# %%
(o or p)
# Out:
# True

# %% [markdown]
# # String төрөл

# %%
name = 'Sansarsaikhansh'
print(name)
# Out:
# Sansarsaikhansh

# %%
Name = name + 'хөөрхөн'
print(Name)
# Out:
# Sansarsaikhanshхөөрхөн

# %%
from __future__ import print_function
Name = Name * 2
print(Name)
# Out:
# SansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөнSansarsaikhanshхөөрхөнхөөрхөн

# %%
name1 = name - 'хөөрхөн'
name1.strip(name1)
print(name1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1794/2666629911.py in <cell line: 0>()
# ----> 1 name1 = name - 'хөөрхөн'
#       2 name1.strip(name1)
#       3 print(name1)
#
# NameError: name 'name' is not defined
