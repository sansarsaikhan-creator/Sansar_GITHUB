# %% [markdown]
# <a href="https://colab.research.google.com/github/sansarsaikhan-creator/Sansar_GITHUB/blob/main/less2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Арифметик оператор

# %%
x = 125
y = 13

# %% [markdown]
# Addition, sub, multi

# %%
z = x+y
q = x-y
w = x*y
print(z)
print(q)
print(w)
# Out:
# 138
# 112
# 1625

# %%
# Үлдэгдэлтэй хуваах (division-float)
div1 = x/y
div1
# Out:
# 9.615384615384615

# %%
# Бүхэлчилж хуваах (division-floor)
div2 = x//y
div2
# Out:
# 9

# %%
# Үлдэгдэл (modulus)
div3 = x % y
div3
# Out:
# 8

# %% [markdown]
# ## Харьцуулалтын оператор (Relational operator )

# %%
a = 120
b = 49

# %%
#greator than
print(a>b)
# Out:
# True

# %%
#less than
print(a<b)
# Out:
# False

# %%
#equal to
print(a==b)
# Out:
# False

# %%
#not equal to
print(a!=b)
# Out:
# True

# %% [markdown]
# ## Логик операторууд LOGICAL OPERATORS

# %%
a = True
b = False

# %%
#logical and
print(a and b)
# Out:
# False

# %%
#logical or
print (a or b or b or b or b)
# Out:
# True

# %%
#logical not
print(not a)
print(not b)
print(not b and a)
# Out:
# False
# True
# True

# %% [markdown]
# ## Утга оноох ASSIGMENT OPERATORS

# %%
a = 15
# add And
a +=20
print(a)
# Out:
# 35

# %%
# subract and
a -= 7
# a = a - 7

# %%
print(a)
# Out:
# 28

# %%
# multiply and
a*=7
print(a)
# Out:
# 196

# %%
# divide and
a /=7
print(a)
# Out:
# 28.0

# %%
type(a)
# Out:
# float

# %%
# modulus and
a = int (a)
a %=8
print(a)
# Out:
# 4

# %%
type(a)
# Out:
# int

# %%
#divide(floor) and
a//=2
print(a)
# Out:
# 2

# %%
# зэрэгт дэвшүүлэх
a = 2
a **= 3
print(a)
# Out:
# 8

# %% [markdown]
# ## Identity operator
